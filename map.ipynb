# %% [markdown]
# ## <center> Python Geospatial Data Analysis

# %% [markdown]
# ### <center>Instructor: Vinita Silaparasetty

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import folium
#https://python-visualization.github.io/folium/
import math
from folium.plugins import MarkerCluster,HeatMap,CirclePattern
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import datetime
from plotly.subplots import make_subplots

# %% [markdown]
# ### Import Data

# %%
df=pd.read_csv('https://raw.githubusercontent.com/VinitaSilaparasetty/coursera-spatial-data-analysis/master/boston-crime%202.csv')
df.head(3)
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP  \
# 0      I192082859           724         Auto Theft
# 1      I192082751           724         Auto Theft
# 2      I192082680           727         Auto Theft
#
#                   OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  SHOOTING  \
# 0                          AUTO THEFT      E18            519       NaN
# 1                          AUTO THEFT      E18            493       NaN
# 2  AUTO THEFT - LEASED/RENTED VEHICLE      D14            794       NaN
#
#       OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  UCR_PART  \
# 0  2019-10-13 09:28:24  2019     10      Sunday     9  Part One
# 1  2019-10-12 20:11:26  2019     10    Saturday    20  Part One
# 2  2019-10-12 15:12:43  2019     10    Saturday    15  Part One
#
#              STREET        Lat       Long                     Location  \
# 0        LINCOLN ST  42.259518 -71.121563  (42.25951765, -71.12156299)
# 1  METROPOLITAN AVE  42.262092 -71.116710  (42.26209214, -71.11670964)
# 2        ALLSTON ST  42.352375 -71.135096  (42.35237455, -71.13509584)
#
#          Date      Time
# 0  2019-10-13  09:28:24
# 1  2019-10-12  20:11:26
# 2  2019-10-12  15:12:43

# %% [markdown]
# ### Generate Base Map

# %%
boston=(42.358443, -71.05977)
m=folium.Map(location=boston, tiles="STamen Terrain", zoom_start=12)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Mark Crime Scenes

# %%
# marker clustering utility helps you to manage multiple markers at different zoom levels. When a user views the map at a high zoom level, the individual markers show on the map. When the user zooms out, the markers gather together into clusters, to make viewing the map easier.
mc=MarkerCluster()

# %%
for idx,row in df.iterrows():
    print(idx)
    print(row)
    if not math.isnan(row['Long']) and not math.isnan(row['Lat']):
        mc.add_child(folium.Marker([row['Lat'], row['Long']]))
m.add_child(mc)
# Out:
# 0
# INCIDENT_NUMBER                         I192082859
# OFFENSE_CODE                                   724
# OFFENSE_CODE_GROUP                      Auto Theft
# OFFENSE_DESCRIPTION                     AUTO THEFT
# DISTRICT                                       E18
# REPORTING_AREA                                 519
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-10-13 09:28:24
# YEAR                                          2019
# MONTH                                           10
# DAY_OF_WEEK                                 Sunday
# HOUR                                             9
# UCR_PART                                  Part One
# STREET                                  LINCOLN ST
# Lat                                        42.2595
# Long                                      -71.1216
# Location               (42.25951765, -71.12156299)
# Date                                    2019-10-13
# Time                                      09:28:24
# Name: 0, dtype: object
# 1
# INCIDENT_NUMBER                         I192082751
# OFFENSE_CODE                                   724
# OFFENSE_CODE_GROUP                      Auto Theft
# OFFENSE_DESCRIPTION                     AUTO THEFT
# DISTRICT                                       E18
# REPORTING_AREA                                 493
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-10-12 20:11:26
# YEAR                                          2019
# MONTH                                           10
# DAY_OF_WEEK                               Saturday
# HOUR                                            20
# UCR_PART                                  Part One
# STREET                            METROPOLITAN AVE
# Lat                                        42.2621
# Long                                      -71.1167
# Location               (42.26209214, -71.11670964)
# Date                                    2019-10-12
# Time                                      20:11:26
# Name: 1, dtype: object
# 2
# INCIDENT_NUMBER                                I192082680
# OFFENSE_CODE                                          727
# OFFENSE_CODE_GROUP                             Auto Theft
# OFFENSE_DESCRIPTION    AUTO THEFT - LEASED/RENTED VEHICLE
# DISTRICT                                              D14
# REPORTING_AREA                                        794
# SHOOTING                                              NaN
# OCCURRED_ON_DATE                      2019-10-12 15:12:43
# YEAR                                                 2019
# MONTH                                                  10
# DAY_OF_WEEK                                      Saturday
# HOUR                                                   15
# UCR_PART                                         Part One
# STREET                                         ALLSTON ST
# Lat                                               42.3524
# Long                                             -71.1351
# Location                      (42.35237455, -71.13509584)
# Date                                           2019-10-12
# Time                                             15:12:43
# Name: 2, dtype: object
# 3
# INCIDENT_NUMBER                         I192082577
# OFFENSE_CODE                                   724
# OFFENSE_CODE_GROUP                      Auto Theft
# OFFENSE_DESCRIPTION                     AUTO THEFT
# DISTRICT                                        D4
# REPORTING_AREA                                 130
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-10-12 04:41:52
# YEAR                                          2019
# MONTH                                           10
# DAY_OF_WEEK                               Saturday
# HOUR                                             4
# UCR_PART                                  Part One
# STREET                             SAINT JAMES AVE
# Lat                                        42.3495
# Long                                      -71.0764
# Location               (42.34947586, -71.07640150)
# Date                                    2019-10-12
# Time                                      04:41:52
# Name: 3, dtype: object
# 4
# INCIDENT_NUMBER                                I192079582
# OFFENSE_CODE                                          727
# OFFENSE_CODE_GROUP                             Auto Theft
# OFFENSE_DESCRIPTION    AUTO THEFT - LEASED/RENTED VEHICLE
# DISTRICT                                              A15
# REPORTING_AREA                                         47
# SHOOTING                                              NaN
# OCCURRED_ON_DATE                      2019-10-02 08:08:49
# YEAR                                                 2019
# MONTH                                                  10
# DAY_OF_WEEK                                     Wednesday
# HOUR                                                    8
# UCR_PART                                         Part One
# STREET                                          N MEAD ST
# Lat                                               42.3818
# Long                                             -71.0666
# Location                      (42.38184582, -71.06655134)
# Date                                           2019-10-02
# Time                                             08:08:49
# Name: 4, dtype: object
# 5
# INCIDENT_NUMBER                         I192078648
# OFFENSE_CODE                                  3114
# OFFENSE_CODE_GROUP            Investigate Property
# OFFENSE_DESCRIPTION           INVESTIGATE PROPERTY
# DISTRICT                                        B3
# REPORTING_AREA                                 427
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 06:39:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             6
# UCR_PART                                Part Three
# STREET                                  WILMORE ST
# Lat                                         42.278
# Long                                      -71.0925
# Location               (42.27796370, -71.09246318)
# Date                                    2019-09-29
# Time                                      06:39:00
# Name: 5, dtype: object
# 6
# INCIDENT_NUMBER                         I192078647
# OFFENSE_CODE                                  3115
# OFFENSE_CODE_GROUP              Investigate Person
# OFFENSE_DESCRIPTION             INVESTIGATE PERSON
# DISTRICT                                        A1
# REPORTING_AREA
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 03:45:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             3
# UCR_PART                                Part Three
# STREET                                   NASHUA ST
# Lat                                        42.3677
# Long                                      -71.0659
# Location               (42.36769032, -71.06586347)
# Date                                    2019-09-29
# Time                                      03:45:00
# Name: 6, dtype: object
# 7
# INCIDENT_NUMBER                         I192078645
# OFFENSE_CODE                                  3301
# OFFENSE_CODE_GROUP                 Verbal Disputes
# OFFENSE_DESCRIPTION                 VERBAL DISPUTE
# DISTRICT                                        B3
# REPORTING_AREA                                 450
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 06:00:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             6
# UCR_PART                                Part Three
# STREET                                ASPINWALL RD
# Lat                                        42.2918
# Long                                      -71.0724
# Location               (42.29181580, -71.07244098)
# Date                                    2019-09-29
# Time                                      06:00:00
# Name: 7, dtype: object
# 8
# INCIDENT_NUMBER                         I192078645
# OFFENSE_CODE                                  1402
# OFFENSE_CODE_GROUP                       Vandalism
# OFFENSE_DESCRIPTION                      VANDALISM
# DISTRICT                                        B3
# REPORTING_AREA                                 450
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 06:00:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             6
# UCR_PART                                  Part Two
# STREET                                ASPINWALL RD
# Lat                                        42.2918
# Long                                      -71.0724
# Location               (42.29181580, -71.07244098)
# Date                                    2019-09-29
# Time                                      06:00:00
# Name: 8, dtype: object
# 9
# INCIDENT_NUMBER                                        I192078642
# OFFENSE_CODE                                                 3820
# OFFENSE_CODE_GROUP                Motor Vehicle Accident Response
# OFFENSE_DESCRIPTION    M/V ACCIDENT INVOLVING PEDESTRIAN - INJURY
# DISTRICT                                                       D4
# REPORTING_AREA                                                269
# SHOOTING                                                      NaN
# OCCURRED_ON_DATE                              2019-09-29 05:50:00
# YEAR                                                         2019
# MONTH                                                           9
# DAY_OF_WEEK                                                Sunday
# HOUR                                                            5
# UCR_PART                                               Part Three
# STREET                                                  ALBANY ST
# Lat                                                       42.3324
# Long                                                      -71.075
# Location                              (42.33241896, -71.07501315)
# Date                                                   2019-09-29
# Time                                                     05:50:00
# Name: 9, dtype: object
# 10
# INCIDENT_NUMBER                         I192078640
# OFFENSE_CODE                                  3115
# OFFENSE_CODE_GROUP              Investigate Person
# OFFENSE_DESCRIPTION             INVESTIGATE PERSON
# DISTRICT                                        A7
# REPORTING_AREA                                  28
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 01:30:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             1
# UCR_PART                                Part Three
# STREET                                    PARIS ST
# Lat                                        42.3734
# Long                                      -71.0365
# Location               (42.37339168, -71.03647779)
# Date                                    2019-09-29
# Time                                      01:30:00
# Name: 10, dtype: object
# 11
# INCIDENT_NUMBER                         I192078638
# OFFENSE_CODE                                  1402
# OFFENSE_CODE_GROUP                       Vandalism
# OFFENSE_DESCRIPTION                      VANDALISM
# DISTRICT                                        A1
# REPORTING_AREA                                  75
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 04:46:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             4
# UCR_PART                                  Part Two
# STREET                                 CAUSEWAY ST
# Lat                                        42.3643
# Long                                      -71.0632
# Location               (42.36433126, -71.06319318)
# Date                                    2019-09-29
# Time                                      04:46:00
# Name: 11, dtype: object
# 12
# INCIDENT_NUMBER                         I192078638
# OFFENSE_CODE                                   423
# OFFENSE_CODE_GROUP              Aggravated Assault
# OFFENSE_DESCRIPTION           ASSAULT - AGGRAVATED
# DISTRICT                                        A1
# REPORTING_AREA                                  75
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 04:46:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             4
# UCR_PART                                  Part One
# STREET                                 CAUSEWAY ST
# Lat                                        42.3643
# Long                                      -71.0632
# Location               (42.36433126, -71.06319318)
# Date                                    2019-09-29
# Time                                      04:46:00
# Name: 12, dtype: object
# 13
# INCIDENT_NUMBER                         I192078637
# OFFENSE_CODE                                  3114
# OFFENSE_CODE_GROUP            Investigate Property
# OFFENSE_DESCRIPTION           INVESTIGATE PROPERTY
# DISTRICT                                        E5
# REPORTING_AREA                                 563
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 04:57:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             4
# UCR_PART                                Part Three
# STREET                                    FIRTH RD
# Lat                                        42.2886
# Long                                      -71.1258
# Location               (42.28861715, -71.12579957)
# Date                                    2019-09-29
# Time                                      04:57:00
# Name: 13, dtype: object
# 14
# INCIDENT_NUMBER                              I192078636
# OFFENSE_CODE                                        521
# OFFENSE_CODE_GROUP                 Residential Burglary
# OFFENSE_DESCRIPTION    BURGLARY - RESIDENTIAL - ATTEMPT
# DISTRICT                                             B2
# REPORTING_AREA                                      316
# SHOOTING                                            NaN
# OCCURRED_ON_DATE                    2019-09-29 04:40:00
# YEAR                                               2019
# MONTH                                                 9
# DAY_OF_WEEK                                      Sunday
# HOUR                                                  4
# UCR_PART                                       Part One
# STREET                                    ABBOTSFORD ST
# Lat                                             42.3146
# Long                                           -71.0926
# Location                    (42.31462973, -71.09261520)
# Date                                         2019-09-29
# Time                                           04:40:00
# Name: 14, dtype: object
# 15
# INCIDENT_NUMBER                         I192078635
# OFFENSE_CODE                                  3301
# OFFENSE_CODE_GROUP                 Verbal Disputes
# OFFENSE_DESCRIPTION                 VERBAL DISPUTE
# DISTRICT                                        B3
# REPORTING_AREA                                 466
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-28 23:55:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                               Saturday
# HOUR                                            23
# UCR_PART                                Part Three
# STREET                                  GOODALE RD
# Lat                                        42.2836
# Long                                      -71.0935
# Location               (42.28362830, -71.09349553)
# Date                                    2019-09-28
# Time                                      23:55:00
# Name: 15, dtype: object
# 16
# INCIDENT_NUMBER                                   I192078633
# OFFENSE_CODE                                            3831
# OFFENSE_CODE_GROUP           Motor Vehicle Accident Response
# OFFENSE_DESCRIPTION    M/V - LEAVING SCENE - PROPERTY DAMAGE
# DISTRICT                                                  B3
# REPORTING_AREA                                           436
# SHOOTING                                                 NaN
# OCCURRED_ON_DATE                         2019-09-29 00:43:00
# YEAR                                                    2019
# MONTH                                                      9
# DAY_OF_WEEK                                           Sunday
# HOUR                                                       0
# UCR_PART                                          Part Three
# STREET                                          WENTWORTH ST
# Lat                                                  42.2876
# Long                                                -71.0753
# Location                         (42.28757867, -71.07527310)
# Date                                              2019-09-29
# Time                                                00:43:00
# Name: 16, dtype: object
# 17
# INCIDENT_NUMBER                         I192078632
# OFFENSE_CODE                                  3301
# OFFENSE_CODE_GROUP                 Verbal Disputes
# OFFENSE_DESCRIPTION                 VERBAL DISPUTE
# DISTRICT                                        B3
# REPORTING_AREA                                 429
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 00:33:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             0
# UCR_PART                                Part Three
# STREET                                  HARWOOD ST
# Lat                                        42.2858
# Long                                      -71.0876
# Location               (42.28576510, -71.08763245)
# Date                                    2019-09-29
# Time                                      00:33:00
# Name: 17, dtype: object
# 18
# INCIDENT_NUMBER                         I192078628
# OFFENSE_CODE                                  3115
# OFFENSE_CODE_GROUP              Investigate Person
# OFFENSE_DESCRIPTION             INVESTIGATE PERSON
# DISTRICT                                        B2
# REPORTING_AREA                                 328
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 03:19:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             3
# UCR_PART                                Part Three
# STREET                                 MAGNOLIA ST
# Lat                                        42.3119
# Long                                      -71.0734
# Location               (42.31193478, -71.07341982)
# Date                                    2019-09-29
# Time                                      03:19:00
# Name: 18, dtype: object
# 19
# INCIDENT_NUMBER                         I192078624
# OFFENSE_CODE                                  3301
# OFFENSE_CODE_GROUP                 Verbal Disputes
# OFFENSE_DESCRIPTION                 VERBAL DISPUTE
# DISTRICT                                        B2
# REPORTING_AREA                                 311
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 00:19:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             0
# UCR_PART                                Part Three
# STREET                                  MAYWOOD ST
# Lat                                        42.3179
# Long                                       -71.081
# Location               (42.31785924, -71.08103560)
# Date                                    2019-09-29
# Time                                      00:19:00
# Name: 19, dtype: object
# 20
# INCIDENT_NUMBER                             I192078623
# OFFENSE_CODE                                      3802
# OFFENSE_CODE_GROUP     Motor Vehicle Accident Response
# OFFENSE_DESCRIPTION    M/V ACCIDENT - PROPERTY  DAMAGE
# DISTRICT                                           C11
# REPORTING_AREA                                     400
# SHOOTING                                           NaN
# OCCURRED_ON_DATE                   2019-09-28 22:40:00
# YEAR                                              2019
# MONTH                                                9
# DAY_OF_WEEK                                   Saturday
# HOUR                                                22
# UCR_PART                                    Part Three
# STREET                                     MONTAGUE ST
# Lat                                            42.2861
# Long                                            -71.07
# Location                   (42.28606484, -71.07001038)
# Date                                        2019-09-28
# Time                                          22:40:00
# Name: 20, dtype: object
# 21
# INCIDENT_NUMBER                         I192078622
# OFFENSE_CODE                                   619
# OFFENSE_CODE_GROUP                         Larceny
# OFFENSE_DESCRIPTION             LARCENY ALL OTHERS
# DISTRICT                                        C6
# REPORTING_AREA                                 201
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 03:04:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             3
# UCR_PART                                  Part One
# STREET                                  W BROADWAY
# Lat                                        42.3401
# Long                                      -71.0528
# Location               (42.34006986, -71.05279420)
# Date                                    2019-09-29
# Time                                      03:04:00
# Name: 21, dtype: object
# 22
# INCIDENT_NUMBER                                           I192078621
# OFFENSE_CODE                                                    1501
# OFFENSE_CODE_GROUP                                Firearm Violations
# OFFENSE_DESCRIPTION    WEAPON - FIREARM - CARRYING / POSSESSING, ETC
# DISTRICT                                                          B3
# REPORTING_AREA                                                   421
# SHOOTING                                                         NaN
# OCCURRED_ON_DATE                                 2019-09-29 03:09:00
# YEAR                                                            2019
# MONTH                                                              9
# DAY_OF_WEEK                                                   Sunday
# HOUR                                                               3
# UCR_PART                                                    Part Two
# STREET                                                   W SELDEN ST
# Lat                                                          42.2797
# Long                                                        -71.0838
# Location                                 (42.27967492, -71.08381263)
# Date                                                      2019-09-29
# Time                                                        03:09:00
# Name: 22, dtype: object
# 23
# INCIDENT_NUMBER                           I192078619
# OFFENSE_CODE                                    3006
# OFFENSE_CODE_GROUP                Medical Assistance
# OFFENSE_DESCRIPTION    SICK/INJURED/MEDICAL - PERSON
# DISTRICT                                          A1
# REPORTING_AREA                                   111
# SHOOTING                                         NaN
# OCCURRED_ON_DATE                 2019-09-29 01:00:00
# YEAR                                            2019
# MONTH                                              9
# DAY_OF_WEEK                                   Sunday
# HOUR                                               1
# UCR_PART                                  Part Three
# STREET                                    TREMONT ST
# Lat                                          42.3559
# Long                                        -71.0626
# Location                 (42.35594239, -71.06258333)
# Date                                      2019-09-29
# Time                                        01:00:00
# Name: 23, dtype: object
# 24
# INCIDENT_NUMBER                             I192078615
# OFFENSE_CODE                                      3803
# OFFENSE_CODE_GROUP     Motor Vehicle Accident Response
# OFFENSE_DESCRIPTION     M/V ACCIDENT - PERSONAL INJURY
# DISTRICT                                            A7
# REPORTING_AREA                                      25
# SHOOTING                                           NaN
# OCCURRED_ON_DATE                   2019-09-29 02:25:00
# YEAR                                              2019
# MONTH                                                9
# DAY_OF_WEEK                                     Sunday
# HOUR                                                 2
# UCR_PART                                    Part Three
# STREET                                       CONDOR ST
# Lat                                            42.3826
# Long                                          -71.0334
# Location                   (42.38258915, -71.03341969)
# Date                                        2019-09-29
# Time                                          02:25:00
# Name: 24, dtype: object
# 25
# INCIDENT_NUMBER                         I192078613
# OFFENSE_CODE                                   423
# OFFENSE_CODE_GROUP              Aggravated Assault
# OFFENSE_DESCRIPTION           ASSAULT - AGGRAVATED
# DISTRICT                                        A7
# REPORTING_AREA                                  17
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 02:30:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             2
# UCR_PART                                  Part One
# STREET                                  CHELSEA ST
# Lat                                        42.3791
# Long                                      -71.0281
# Location               (42.37912370, -71.02808210)
# Date                                    2019-09-29
# Time                                      02:30:00
# Name: 25, dtype: object
# 26
# INCIDENT_NUMBER                         I192078613
# OFFENSE_CODE                                   802
# OFFENSE_CODE_GROUP                  Simple Assault
# OFFENSE_DESCRIPTION       ASSAULT SIMPLE - BATTERY
# DISTRICT                                        A7
# REPORTING_AREA                                  17
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 02:30:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             2
# UCR_PART                                  Part Two
# STREET                                  CHELSEA ST
# Lat                                        42.3791
# Long                                      -71.0281
# Location               (42.37912370, -71.02808210)
# Date                                    2019-09-29
# Time                                      02:30:00
# Name: 26, dtype: object
# 27
# INCIDENT_NUMBER                         I192078612
# OFFENSE_CODE                                  3114
# OFFENSE_CODE_GROUP            Investigate Property
# OFFENSE_DESCRIPTION           INVESTIGATE PROPERTY
# DISTRICT                                       D14
# REPORTING_AREA                                 800
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 02:39:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             2
# UCR_PART                                Part Three
# STREET                                BRIGHTON AVE
# Lat                                        42.3527
# Long                                      -71.1293
# Location               (42.35272466, -71.12927406)
# Date                                    2019-09-29
# Time                                      02:39:00
# Name: 27, dtype: object
# 28
# INCIDENT_NUMBER                         I192078611
# OFFENSE_CODE                                  1402
# OFFENSE_CODE_GROUP                       Vandalism
# OFFENSE_DESCRIPTION                      VANDALISM
# DISTRICT                                       D14
# REPORTING_AREA                                 789
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 01:30:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             1
# UCR_PART                                  Part Two
# STREET                                 BRAEMORE RD
# Lat                                        42.3384
# Long                                      -71.1516
# Location               (42.33840140, -71.15158388)
# Date                                    2019-09-29
# Time                                      01:30:00
# Name: 28, dtype: object
# 29
# INCIDENT_NUMBER                         I192078610
# OFFENSE_CODE                                  3501
# OFFENSE_CODE_GROUP         Missing Person Reported
# OFFENSE_DESCRIPTION                 MISSING PERSON
# DISTRICT                                        D4
# REPORTING_AREA                                 145
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 01:53:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             1
# UCR_PART                                Part Three
# STREET                                   DURHAM ST
# Lat                                         42.344
# Long                                      -71.0812
# Location               (42.34403563, -71.08117746)
# Date                                    2019-09-29
# Time                                      01:53:00
# Name: 29, dtype: object
# 30
# INCIDENT_NUMBER                         I192078609
# OFFENSE_CODE                                   301
# OFFENSE_CODE_GROUP                         Robbery
# OFFENSE_DESCRIPTION               ROBBERY - STREET
# DISTRICT                                        A1
# REPORTING_AREA                                 119
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 01:01:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             1
# UCR_PART                                  Part One
# STREET                                  TREMONT ST
# Lat                                        42.3564
# Long                                      -71.0621
# Location               (42.35637531, -71.06213513)
# Date                                    2019-09-29
# Time                                      01:01:00
# Name: 30, dtype: object
# 31
# INCIDENT_NUMBER                         I192078608
# OFFENSE_CODE                                   801
# OFFENSE_CODE_GROUP                  Simple Assault
# OFFENSE_DESCRIPTION               ASSAULT - SIMPLE
# DISTRICT                                       E18
# REPORTING_AREA                                 501
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 01:35:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             1
# UCR_PART                                  Part Two
# STREET                               CANTERBURY ST
# Lat                                        42.2787
# Long                                      -71.1173
# Location               (42.27868789, -71.11734430)
# Date                                    2019-09-29
# Time                                      01:35:00
# Name: 31, dtype: object
# 32
# INCIDENT_NUMBER                         I192078607
# OFFENSE_CODE                                  3114
# OFFENSE_CODE_GROUP            Investigate Property
# OFFENSE_DESCRIPTION           INVESTIGATE PROPERTY
# DISTRICT                                       D14
# REPORTING_AREA                                 749
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 01:20:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             1
# UCR_PART                                Part Three
# STREET                            COMMONWEALTH AVE
# Lat                                        42.3391
# Long                                      -71.1564
# Location               (42.33906470, -71.15642795)
# Date                                    2019-09-29
# Time                                      01:20:00
# Name: 32, dtype: object
# 33
# INCIDENT_NUMBER                         I192078606
# OFFENSE_CODE                                  3201
# OFFENSE_CODE_GROUP                   Property Lost
# OFFENSE_DESCRIPTION                PROPERTY - LOST
# DISTRICT                                        C6
# REPORTING_AREA                                 200
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 02:21:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             2
# UCR_PART                                Part Three
# STREET                                  W BROADWAY
# Lat                                        42.3413
# Long                                      -71.0547
# Location               (42.34128751, -71.05467933)
# Date                                    2019-09-29
# Time                                      02:21:00
# Name: 33, dtype: object
# 34
# INCIDENT_NUMBER                              I192078604
# OFFENSE_CODE                                       2906
# OFFENSE_CODE_GROUP                           Violations
# OFFENSE_DESCRIPTION    VAL - OPERATING UNREG/UNINS  CAR
# DISTRICT                                             B2
# REPORTING_AREA                                      267
# SHOOTING                                            NaN
# OCCURRED_ON_DATE                    2019-09-29 01:45:00
# YEAR                                               2019
# MONTH                                                 9
# DAY_OF_WEEK                                      Sunday
# HOUR                                                  1
# UCR_PART                                       Part Two
# STREET                                        DUDLEY ST
# Lat                                             42.3264
# Long                                           -71.0758
# Location                    (42.32643963, -71.07577308)
# Date                                         2019-09-29
# Time                                           01:45:00
# Name: 34, dtype: object
# 35
# INCIDENT_NUMBER                             I192078604
# OFFENSE_CODE                                      2907
# OFFENSE_CODE_GROUP                          Violations
# OFFENSE_DESCRIPTION    VAL - OPERATING AFTER REV/SUSP.
# DISTRICT                                            B2
# REPORTING_AREA                                     267
# SHOOTING                                           NaN
# OCCURRED_ON_DATE                   2019-09-29 01:45:00
# YEAR                                              2019
# MONTH                                                9
# DAY_OF_WEEK                                     Sunday
# HOUR                                                 1
# UCR_PART                                      Part Two
# STREET                                       DUDLEY ST
# Lat                                            42.3264
# Long                                          -71.0758
# Location                   (42.32643963, -71.07577308)
# Date                                        2019-09-29
# Time                                          01:45:00
# Name: 35, dtype: object
# 36
# INCIDENT_NUMBER                         I192078603
# OFFENSE_CODE                                   301
# OFFENSE_CODE_GROUP                         Robbery
# OFFENSE_DESCRIPTION               ROBBERY - STREET
# DISTRICT                                        A7
# REPORTING_AREA                                  23
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 01:30:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             1
# UCR_PART                                  Part One
# STREET                               BENNINGTON ST
# Lat                                        42.3755
# Long                                      -71.0373
# Location               (42.37546983, -71.03730221)
# Date                                    2019-09-29
# Time                                      01:30:00
# Name: 36, dtype: object
# 37
# INCIDENT_NUMBER                         I192078603
# OFFENSE_CODE                                   802
# OFFENSE_CODE_GROUP                  Simple Assault
# OFFENSE_DESCRIPTION       ASSAULT SIMPLE - BATTERY
# DISTRICT                                        A7
# REPORTING_AREA                                  23
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 01:30:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             1
# UCR_PART                                  Part Two
# STREET                               BENNINGTON ST
# Lat                                        42.3755
# Long                                      -71.0373
# Location               (42.37546983, -71.03730221)
# Date                                    2019-09-29
# Time                                      01:30:00
# Name: 37, dtype: object
# 38
# INCIDENT_NUMBER                         I192078602
# OFFENSE_CODE                                  3125
# OFFENSE_CODE_GROUP                 Warrant Arrests
# OFFENSE_DESCRIPTION                 WARRANT ARREST
# DISTRICT                                        B3
# REPORTING_AREA                                 465
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 01:50:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             1
# UCR_PART                                Part Three
# STREET                               BLUE HILL AVE
# Lat                                        42.2848
# Long                                      -71.0914
# Location               (42.28482577, -71.09137369)
# Date                                    2019-09-29
# Time                                      01:50:00
# Name: 38, dtype: object
# 39
# INCIDENT_NUMBER                                   I192078602
# OFFENSE_CODE                                            3119
# OFFENSE_CODE_GROUP                         Firearm Discovery
# OFFENSE_DESCRIPTION    FIREARM/WEAPON - FOUND OR CONFISCATED
# DISTRICT                                                  B3
# REPORTING_AREA                                           465
# SHOOTING                                                 NaN
# OCCURRED_ON_DATE                         2019-09-29 01:50:00
# YEAR                                                    2019
# MONTH                                                      9
# DAY_OF_WEEK                                           Sunday
# HOUR                                                       1
# UCR_PART                                          Part Three
# STREET                                         BLUE HILL AVE
# Lat                                                  42.2848
# Long                                                -71.0914
# Location                         (42.28482577, -71.09137369)
# Date                                              2019-09-29
# Time                                                01:50:00
# Name: 39, dtype: object
# 40
# INCIDENT_NUMBER                                           I192078602
# OFFENSE_CODE                                                    1501
# OFFENSE_CODE_GROUP                                Firearm Violations
# OFFENSE_DESCRIPTION    WEAPON - FIREARM - CARRYING / POSSESSING, ETC
# DISTRICT                                                          B3
# REPORTING_AREA                                                   465
# SHOOTING                                                         NaN
# OCCURRED_ON_DATE                                 2019-09-29 01:50:00
# YEAR                                                            2019
# MONTH                                                              9
# DAY_OF_WEEK                                                   Sunday
# HOUR                                                               1
# UCR_PART                                                    Part Two
# STREET                                                 BLUE HILL AVE
# Lat                                                          42.2848
# Long                                                        -71.0914
# Location                                 (42.28482577, -71.09137369)
# Date                                                      2019-09-29
# Time                                                        01:50:00
# Name: 40, dtype: object
# 41
# INCIDENT_NUMBER                              I192078602
# OFFENSE_CODE                                       1504
# OFFENSE_CODE_GROUP                                Other
# OFFENSE_DESCRIPTION    WEAPON - OTHER - OTHER VIOLATION
# DISTRICT                                             B3
# REPORTING_AREA                                      465
# SHOOTING                                            NaN
# OCCURRED_ON_DATE                    2019-09-29 01:50:00
# YEAR                                               2019
# MONTH                                                 9
# DAY_OF_WEEK                                      Sunday
# HOUR                                                  1
# UCR_PART                                       Part Two
# STREET                                    BLUE HILL AVE
# Lat                                             42.2848
# Long                                           -71.0914
# Location                    (42.28482577, -71.09137369)
# Date                                         2019-09-29
# Time                                           01:50:00
# Name: 41, dtype: object
# 42
# INCIDENT_NUMBER                         I192078601
# OFFENSE_CODE                                  3501
# OFFENSE_CODE_GROUP         Missing Person Reported
# OFFENSE_DESCRIPTION                 MISSING PERSON
# DISTRICT                                        B2
# REPORTING_AREA                                 587
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-28 22:15:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                               Saturday
# HOUR                                            22
# UCR_PART                                Part Three
# STREET                                ALLEGHANY ST
# Lat                                        42.3306
# Long                                      -71.0996
# Location               (42.33056977, -71.09959089)
# Date                                    2019-09-28
# Time                                      22:15:00
# Name: 42, dtype: object
# 43
# INCIDENT_NUMBER                            I192078600
# OFFENSE_CODE                                      413
# OFFENSE_CODE_GROUP                 Aggravated Assault
# OFFENSE_DESCRIPTION    ASSAULT - AGGRAVATED - BATTERY
# DISTRICT                                          C11
# REPORTING_AREA                                    340
# SHOOTING                                          NaN
# OCCURRED_ON_DATE                  2019-09-29 00:08:40
# YEAR                                             2019
# MONTH                                               9
# DAY_OF_WEEK                                    Sunday
# HOUR                                                0
# UCR_PART                                     Part One
# STREET                                     BOWDOIN ST
# Lat                                           42.3081
# Long                                         -71.0646
# Location                  (42.30811103, -71.06458431)
# Date                                       2019-09-29
# Time                                         00:08:40
# Name: 43, dtype: object
# 44
# INCIDENT_NUMBER                         I192078599
# OFFENSE_CODE                                  1402
# OFFENSE_CODE_GROUP                       Vandalism
# OFFENSE_DESCRIPTION                      VANDALISM
# DISTRICT                                        B2
# REPORTING_AREA                                 238
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-28 23:21:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                               Saturday
# HOUR                                            23
# UCR_PART                                  Part Two
# STREET                                 WENDOVER ST
# Lat                                        42.3188
# Long                                      -71.0661
# Location               (42.31882655, -71.06605368)
# Date                                    2019-09-28
# Time                                      23:21:00
# Name: 44, dtype: object
# 45
# INCIDENT_NUMBER                         I192078597
# OFFENSE_CODE                                  2662
# OFFENSE_CODE_GROUP                      Ballistics
# OFFENSE_DESCRIPTION      BALLISTICS EVIDENCE/FOUND
# DISTRICT                                        B2
# REPORTING_AREA                                 326
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-29 00:58:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Sunday
# HOUR                                             0
# UCR_PART                                  Part Two
# STREET                                  FAYSTON ST
# Lat                                        42.3122
# Long                                      -71.0755
# Location               (42.31224327, -71.07549901)
# Date                                    2019-09-29
# Time                                      00:58:00
# ...
# OCCURRED_ON_DATE                         2019-09-27 08:45:00
# YEAR                                                    2019
# MONTH                                                      9
# DAY_OF_WEEK                                           Friday
# HOUR                                                       8
# UCR_PART                                          Part Three
# STREET                                            RUTLAND ST
# Lat                                                  42.3384
# Long                                                -71.0743
# Location                         (42.33841268, -71.07427827)
# Date                                              2019-09-27
# Time                                                08:45:00
# Name: 457, dtype: object
# 458
# INCIDENT_NUMBER                         I192078081
# OFFENSE_CODE                                  3201
# OFFENSE_CODE_GROUP                   Property Lost
# OFFENSE_DESCRIPTION                PROPERTY - LOST
# DISTRICT                                        D4
# REPORTING_AREA                                 146
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-08-27 13:57:00
# YEAR                                          2019
# MONTH                                            8
# DAY_OF_WEEK                                Tuesday
# HOUR                                            13
# UCR_PART                                Part Three
# STREET                                 HARCOURT ST
# Lat                                        42.3462
# Long                                      -71.0785
# Location               (42.34618775, -71.07852785)
# Date                                    2019-08-27
# Time                                      13:57:00
# Name: 458, dtype: object
# 459
# INCIDENT_NUMBER                           I192078080
# OFFENSE_CODE                                    3006
# OFFENSE_CODE_GROUP                Medical Assistance
# OFFENSE_DESCRIPTION    SICK/INJURED/MEDICAL - PERSON
# DISTRICT                                          A1
# REPORTING_AREA                                   103
# SHOOTING                                         NaN
# OCCURRED_ON_DATE                 2019-09-27 13:28:00
# YEAR                                            2019
# MONTH                                              9
# DAY_OF_WEEK                                   Friday
# HOUR                                              13
# UCR_PART                                  Part Three
# STREET                                   PROVINCE ST
# Lat                                          42.3577
# Long                                        -71.0594
# Location                 (42.35769018, -71.05938775)
# Date                                      2019-09-27
# Time                                        13:28:00
# Name: 459, dtype: object
# 460
# INCIDENT_NUMBER                                            I192078079
# OFFENSE_CODE                                                     1841
# OFFENSE_CODE_GROUP                                     Drug Violation
# OFFENSE_DESCRIPTION    DRUGS - POSS CLASS A - INTENT TO MFR DIST DISP
# DISTRICT                                                          A15
# REPORTING_AREA                                                     41
# SHOOTING                                                          NaN
# OCCURRED_ON_DATE                                  2019-09-27 13:55:00
# YEAR                                                             2019
# MONTH                                                               9
# DAY_OF_WEEK                                                    Friday
# HOUR                                                               13
# UCR_PART                                                     Part Two
# STREET                                                        VINE ST
# Lat                                                           42.3766
# Long                                                         -71.0559
# Location                                  (42.37663167, -71.05593196)
# Date                                                       2019-09-27
# Time                                                         13:55:00
# Name: 460, dtype: object
# 461
# INCIDENT_NUMBER                         I192078078
# OFFENSE_CODE                                  2629
# OFFENSE_CODE_GROUP                      Harassment
# OFFENSE_DESCRIPTION                     HARASSMENT
# DISTRICT                                        D4
# REPORTING_AREA                                 133
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-27 13:04:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Friday
# HOUR                                            13
# UCR_PART                                  Part Two
# STREET                                  NEWBURY ST
# Lat                                        42.3518
# Long                                      -71.0745
# Location               (42.35176179, -71.07452168)
# Date                                    2019-09-27
# Time                                      13:04:00
# Name: 461, dtype: object
# 462
# INCIDENT_NUMBER                         I192078076
# OFFENSE_CODE                                   619
# OFFENSE_CODE_GROUP                         Larceny
# OFFENSE_DESCRIPTION             LARCENY ALL OTHERS
# DISTRICT                                        B3
# REPORTING_AREA                                 438
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-25 18:00:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                              Wednesday
# HOUR                                            18
# UCR_PART                                  Part One
# STREET                                SOUTHERN AVE
# Lat                                        42.2895
# Long                                       -71.078
# Location               (42.28948778, -71.07799371)
# Date                                    2019-09-25
# Time                                      18:00:00
# Name: 462, dtype: object
# 463
# INCIDENT_NUMBER                         I192078073
# OFFENSE_CODE                                   617
# OFFENSE_CODE_GROUP                         Larceny
# OFFENSE_DESCRIPTION    LARCENY THEFT FROM BUILDING
# DISTRICT                                        B2
# REPORTING_AREA                                 278
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-27 12:30:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Friday
# HOUR                                            12
# UCR_PART                                  Part One
# STREET                                HARRISON AVE
# Lat                                        42.3315
# Long                                      -71.0802
# Location               (42.33153805, -71.08015661)
# Date                                    2019-09-27
# Time                                      12:30:00
# Name: 463, dtype: object
# 464
# INCIDENT_NUMBER                             I192078071
# OFFENSE_CODE                                      1102
# OFFENSE_CODE_GROUP                               Fraud
# OFFENSE_DESCRIPTION    FRAUD - FALSE PRETENSE / SCHEME
# DISTRICT                                            C6
# REPORTING_AREA                                     227
# SHOOTING                                           NaN
# OCCURRED_ON_DATE                   2019-09-27 08:00:00
# YEAR                                              2019
# MONTH                                                9
# DAY_OF_WEEK                                     Friday
# HOUR                                                 8
# UCR_PART                                      Part Two
# STREET                                     E FOURTH ST
# Lat                                            42.3348
# Long                                          -71.0325
# Location                   (42.33479672, -71.03248640)
# Date                                        2019-09-27
# Time                                          08:00:00
# Name: 464, dtype: object
# 465
# INCIDENT_NUMBER                         I192078068
# OFFENSE_CODE                                  1402
# OFFENSE_CODE_GROUP                       Vandalism
# OFFENSE_DESCRIPTION                      VANDALISM
# DISTRICT                                        D4
# REPORTING_AREA                                 141
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-27 13:37:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Friday
# HOUR                                            13
# UCR_PART                                  Part Two
# STREET                            COMMONWEALTH AVE
# Lat                                         42.349
# Long                                      -71.0886
# Location               (42.34904891, -71.08859920)
# Date                                    2019-09-27
# Time                                      13:37:00
# Name: 465, dtype: object
# 466
# INCIDENT_NUMBER                         I192078067
# OFFENSE_CODE                                  1402
# OFFENSE_CODE_GROUP                       Vandalism
# OFFENSE_DESCRIPTION                      VANDALISM
# DISTRICT                                        A7
# REPORTING_AREA                                  17
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-26 15:00:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                               Thursday
# HOUR                                            15
# UCR_PART                                  Part Two
# STREET                                   BREMEN ST
# Lat                                        42.3784
# Long                                      -71.0278
# Location               (42.37842947, -71.02778665)
# Date                                    2019-09-26
# Time                                      15:00:00
# Name: 466, dtype: object
# 467
# INCIDENT_NUMBER                                   I192078066
# OFFENSE_CODE                                            3831
# OFFENSE_CODE_GROUP           Motor Vehicle Accident Response
# OFFENSE_DESCRIPTION    M/V - LEAVING SCENE - PROPERTY DAMAGE
# DISTRICT                                                  B2
# REPORTING_AREA                                           259
# SHOOTING                                                 NaN
# OCCURRED_ON_DATE                         2019-09-23 16:15:00
# YEAR                                                    2019
# MONTH                                                      9
# DAY_OF_WEEK                                           Monday
# HOUR                                                      16
# UCR_PART                                          Part Three
# STREET                                           MAGNOLIA ST
# Lat                                                  42.3148
# Long                                                -71.0716
# Location                         (42.31478432, -71.07160997)
# Date                                              2019-09-23
# Time                                                16:15:00
# Name: 467, dtype: object
# 468
# INCIDENT_NUMBER                         I192078065
# OFFENSE_CODE                                   616
# OFFENSE_CODE_GROUP                         Larceny
# OFFENSE_DESCRIPTION       LARCENY THEFT OF BICYCLE
# DISTRICT                                       D14
# REPORTING_AREA                                 759
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-16 10:00:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Monday
# HOUR                                            10
# UCR_PART                                  Part One
# STREET                                  BIGELOW ST
# Lat                                         42.352
# Long                                      -71.1677
# Location               (42.35199741, -71.16768308)
# Date                                    2019-09-16
# Time                                      10:00:00
# Name: 468, dtype: object
# 469
# INCIDENT_NUMBER                         I192078064
# OFFENSE_CODE                                  3201
# OFFENSE_CODE_GROUP                   Property Lost
# OFFENSE_DESCRIPTION                PROPERTY - LOST
# DISTRICT                                        D4
# REPORTING_AREA                                 140
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-08-01 09:00:00
# YEAR                                          2019
# MONTH                                            8
# DAY_OF_WEEK                               Thursday
# HOUR                                             9
# UCR_PART                                Part Three
# STREET                               GLOUCESTER ST
# Lat                                        42.3505
# Long                                      -71.0848
# Location               (42.35053286, -71.08481789)
# Date                                    2019-08-01
# Time                                      09:00:00
# Name: 469, dtype: object
# 470
# INCIDENT_NUMBER                         I192078063
# OFFENSE_CODE                                  3207
# OFFENSE_CODE_GROUP                  Property Found
# OFFENSE_DESCRIPTION               PROPERTY - FOUND
# DISTRICT                                        E5
# REPORTING_AREA                                 691
# SHOOTING                                       NaN
# OCCURRED_ON_DATE               2019-09-27 13:18:00
# YEAR                                          2019
# MONTH                                            9
# DAY_OF_WEEK                                 Friday
# HOUR                                            13
# UCR_PART                                Part Three
# STREET                                   CENTRE ST
# Lat                                        42.2871
# Long                                      -71.1482
# Location               (42.28709355, -71.14822128)
# Date                                    2019-09-27
# Time                                      13:18:00
# Name: 470, dtype: object
# 471
# INCIDENT_NUMBER                           I192078062
# OFFENSE_CODE                                    3006
# OFFENSE_CODE_GROUP                Medical Assistance
# OFFENSE_DESCRIPTION    SICK/INJURED/MEDICAL - PERSON
# DISTRICT                                          D4
# REPORTING_AREA                                   135
# SHOOTING                                         NaN
# OCCURRED_ON_DATE                 2019-09-27 11:23:00
# YEAR                                            2019
# MONTH                                              9
# DAY_OF_WEEK                                   Friday
# HOUR                                              11
# UCR_PART                                  Part Three
# STREET                                     BEACON ST
# Lat                                          42.3534
# Long                                        -71.0802
# Location                 (42.35335717, -71.08017703)
# Date                                      2019-09-27
# Time                                        11:23:00
# Name: 471, dtype: object
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### View Districts with Highest Crime Rates

# %%
crime=df.groupby(['DISTRICT', 'STREET', 'REPORTING_AREA', 'Lat', 'Long']).sum().reset_index()
crime
# Out:
#     DISTRICT        STREET REPORTING_AREA        Lat       Long  OFFENSE_CODE  \
# 0         A1  ARLINGTON ST            128  42.348670 -71.069389          3201
# 1         A1  ATLANTIC AVE            110  42.354009 -71.052853          3831
# 2         A1  ATLANTIC AVE            114  42.354383 -71.052133          2647
# 3         A1   CAUSEWAY ST             75  42.364331 -71.063193          1825
# 4         A1   CAUSEWAY ST             75  42.364975 -71.062044          2405
# ..       ...           ...            ...        ...        ...           ...
# 386       E5      SOUTH ST            676  42.288025 -71.143697          3802
# 387       E5      TOBIN RD            714  42.259006 -71.160679          3301
# 388       E5    TYNDALE ST            672  42.287186 -71.136805          3503
# 389       E5     WALTER ST            663  42.293797 -71.130566          3006
# 390       E5       WELD ST            678  42.293364 -71.144940          3301
#
#      SHOOTING  YEAR  MONTH  HOUR
# 0         0.0  2019      9    10
# 1         0.0  2019      9     3
# 2         0.0  2019      9    15
# 3         0.0  4038     18     8
# 4         0.0  2019      9    21
# ..        ...   ...    ...   ...
# 386       0.0  2019      9    12
# 387       0.0  2019      9    21
# 388       0.0  2019      9    17
# 389       0.0  2019      9    19
# 390       0.0  2019      9    16
#
# [391 rows x 10 columns]

# %%
crime.update(crime['DISTRICT'].map('District:{}'.format))

# %%
crime
# Out:
#         DISTRICT        STREET REPORTING_AREA        Lat       Long  \
# 0    District:A1  ARLINGTON ST            128  42.348670 -71.069389
# 1    District:A1  ATLANTIC AVE            110  42.354009 -71.052853
# 2    District:A1  ATLANTIC AVE            114  42.354383 -71.052133
# 3    District:A1   CAUSEWAY ST             75  42.364331 -71.063193
# 4    District:A1   CAUSEWAY ST             75  42.364975 -71.062044
# ..           ...           ...            ...        ...        ...
# 386  District:E5      SOUTH ST            676  42.288025 -71.143697
# 387  District:E5      TOBIN RD            714  42.259006 -71.160679
# 388  District:E5    TYNDALE ST            672  42.287186 -71.136805
# 389  District:E5     WALTER ST            663  42.293797 -71.130566
# 390  District:E5       WELD ST            678  42.293364 -71.144940
#
#      OFFENSE_CODE  SHOOTING  YEAR  MONTH  HOUR
# 0            3201       0.0  2019      9    10
# 1            3831       0.0  2019      9     3
# 2            2647       0.0  2019      9    15
# 3            1825       0.0  4038     18     8
# 4            2405       0.0  2019      9    21
# ..            ...       ...   ...    ...   ...
# 386          3802       0.0  2019      9    12
# 387          3301       0.0  2019      9    21
# 388          3503       0.0  2019      9    17
# 389          3006       0.0  2019      9    19
# 390          3301       0.0  2019      9    16
#
# [391 rows x 10 columns]

# %%
crime.update(crime['REPORTING_AREA'].map('Reports:{}'.format))

# %%
crime
# Out:
#         DISTRICT        STREET REPORTING_AREA        Lat       Long  \
# 0    District:A1  ARLINGTON ST    Reports:128  42.348670 -71.069389
# 1    District:A1  ATLANTIC AVE    Reports:110  42.354009 -71.052853
# 2    District:A1  ATLANTIC AVE    Reports:114  42.354383 -71.052133
# 3    District:A1   CAUSEWAY ST     Reports:75  42.364331 -71.063193
# 4    District:A1   CAUSEWAY ST     Reports:75  42.364975 -71.062044
# ..           ...           ...            ...        ...        ...
# 386  District:E5      SOUTH ST    Reports:676  42.288025 -71.143697
# 387  District:E5      TOBIN RD    Reports:714  42.259006 -71.160679
# 388  District:E5    TYNDALE ST    Reports:672  42.287186 -71.136805
# 389  District:E5     WALTER ST    Reports:663  42.293797 -71.130566
# 390  District:E5       WELD ST    Reports:678  42.293364 -71.144940
#
#      OFFENSE_CODE  SHOOTING  YEAR  MONTH  HOUR
# 0            3201       0.0  2019      9    10
# 1            3831       0.0  2019      9     3
# 2            2647       0.0  2019      9    15
# 3            1825       0.0  4038     18     8
# 4            2405       0.0  2019      9    21
# ..            ...       ...   ...    ...   ...
# 386          3802       0.0  2019      9    12
# 387          3301       0.0  2019      9    21
# 388          3503       0.0  2019      9    17
# 389          3006       0.0  2019      9    19
# 390          3301       0.0  2019      9    16
#
# [391 rows x 10 columns]

# %%
m2=folium.Map(location=boston, tiles="stamentoner", zoom_start=12)
HeatMap(data=crime[['Lat', 'Long']], radius=15).add_to(m2)
#https://python-visualization.github.io/folium/modules.html search circlemaker 
#circlemaker:A circle of a fixed size with radius specified in pixels.
def plotDot(point):
    folium.vector_layers.CircleMarker(location=[point.Lat,point.Long],
                      radius=5,
                      weight=2,
                      popup=[point.DISTRICT,point.REPORTING_AREA],
                      color='#3186cc',
                      fill_color='#3186cc').add_to(m2)
crime.apply(plotDot,axis=1)
#Computes the bounds of the object itself (not including it’s children) in the form [[lat_min, lon_min], [lat_max, lon_max]]
m2.fit_bounds(m2.get_bounds())
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Medical Assistance Analysis

# %%
med=df.loc[df.OFFENSE_CODE_GROUP=='Medical Assistance'][['Lat', 'Long']]
med
# Out:
#            Lat       Long
# 23   42.355942 -71.062583
# 53   42.307342 -71.105441
# 58   42.309692 -71.072859
# 73   42.341288 -71.054679
# 75   42.320778 -71.105538
# 83   42.319757 -71.054289
# 95   42.276131 -71.087654
# 103  42.319052 -71.084114
# 108  42.285398 -71.156161
# 117  42.343734 -71.074192
# 152  42.323877 -71.104093
# 169  42.276511 -71.134176
# 172  42.318576 -71.087672
# 195  42.313634 -71.067780
# 211  42.278004 -71.069505
# 260  42.374762 -71.037312
# 270  42.351824 -71.133134
# 272  42.353254 -71.048724
# 279  42.364754 -71.054695
# 281  42.361928 -71.070820
# 291  42.330826 -71.104370
# 292  42.351435 -71.069693
# 293  42.310749 -71.107662
# 295  42.370261 -71.042900
# 297  42.376203 -71.039799
# 299  42.257675 -71.123671
# 300  42.304613 -71.072966
# 304  42.354136 -71.141165
# 333  42.293797 -71.130566
# 363  42.285235 -71.055097
# 368  42.382891 -71.039309
# 373  42.358923 -71.058354
# 405  42.282779 -71.071355
# 420  42.317362 -71.077246
# 432  42.343765 -71.088669
# 456  42.339542 -71.069409
# 459  42.357690 -71.059388
# 471  42.353357 -71.080177

# %%
med.Lat.fillna(0,inplace=True)
med.Long.fillna(0,inplace=True)
m6=folium.Map(location=boston,tiles='Openstreetmap',zoom_start=11)
HeatMap(data=med,radius=16).add_to(m6)
m6
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Crimes Commited

# %%
#catplot show the relationship between a numerical and one or more categorical variables using one of several visual representations
sns.catplot(y='OFFENSE_CODE_GROUP', 
            kind = 'count',
            height=8,
            aspect=1.5,
            order=df.OFFENSE_CODE_GROUP.value_counts().index,
            data=df
           )

# %% [markdown]
# ### Motor Vehicle Accident Response

# %%
mv=df.loc[df.OFFENSE_CODE_GROUP=='Motor Vehicle Accident Response'][['Lat', 'Long']]

# %%
mv;
# Out:
#            Lat       Long
# 9    42.332419 -71.075013
# 16   42.287579 -71.075273
# 20   42.286065 -71.070010
# 24   42.382589 -71.033420
# 50   42.339761 -71.057092
# 54   42.264837 -71.099668
# 55   42.270801 -71.105812
# 56   42.325610 -71.104500
# 74   42.363122 -71.130563
# 86   42.302698 -71.066015
# 105  42.304904 -71.074140
# 106  42.350570 -71.167812
# 121  42.348406 -71.086883
# 122  42.335718 -71.030256
# 124  42.334025 -71.090390
# 130  42.265197 -71.126864
# 151  42.364065 -71.063337
# 168  42.371295 -71.043424
# 170  42.305142 -71.058981
# 177  42.280679 -71.158175
# 179  42.381208 -71.069143
# 191  42.346475 -71.051506
# 194  42.311628 -71.080943
# 196  42.283628 -71.093496
# 201  42.288025 -71.143697
# 209  42.302673 -71.070195
# 246  42.264305 -71.100613
# 251  42.317094 -71.078030
# 252  42.325276 -71.059145
# 254  42.354009 -71.052853
# 256  42.307242 -71.085517
# 257  42.286332 -71.086423
# 264  42.274130 -71.116746
# 274  42.303441 -71.066746
# 280  42.314950 -71.105995
# 289  42.332096 -71.098606
# 298  42.287701 -71.106713
# 310  42.318399 -71.075305
# 332  42.347513 -71.136893
# 348  42.335700 -71.031285
# 350  42.323094 -71.109661
# 389  42.383916 -71.022662
# 393  42.326966 -71.061986
# 394  42.378971 -71.059343
# 414  42.349686 -71.082179
# 424  42.275316 -71.110819
# 426  42.337292 -71.037466
# 433  42.378689 -71.053465
# 434  42.303576 -71.068808
# 446  42.353426 -71.135084
# 448  42.321532 -71.077385
# 453  42.319157 -71.100676
# 457  42.338413 -71.074278
# 467  42.314784 -71.071610

# %%
mv.fillna(0, inplace=True)
mv.Lat.fillna(0, inplace=True)
mv.Long.fillna(0, inplace=True)
m4=folium.Map(location=boston, tiles='openstreetmap',zoom_start=11)
HeatMap(data=mv,radius=16).add_to(m4)

# %%
m4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Larceny

# %%
lar=df.loc[df.OFFENSE_CODE_GROUP=='Larceny'][['Lat', 'Long']]

# %%
lar.Lat.fillna(0, inplace=True)
lar.Long.fillna(0, inplace=True)
m5=folium.Map(location=boston, tiles='openstreetmap',zoom_start=11)
HeatMap(data=lar,radius=16).add_to(m5)

# %%
m5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#type this in cmd to extract an html file of these visualization
jupyter nbconvert file.ipynb --no-input --no-prompt
